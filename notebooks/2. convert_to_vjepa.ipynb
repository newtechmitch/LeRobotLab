# %% [markdown]
# # Convert LeRobot to VJEPA Layout
#
# This notebook converts LeRobot datasets to the VJEPA format structure:
#
# **VJEPA Format:**
# ```
# Dataset_folder/
# ├── dataset_list.txt          # CSV file with episode paths (one per line)
# └── episodes/
#     ├── episode_001/
#     ├── episode_002/
#     ├── ...
#     └── episode_N/
# ```
#
# **Episode structure:**
# ```
# episode_n/
# ├── metadata.json             # Episode metadata with file paths
# ├── trajectory.h5             # Robot trajectory and sensor data
# └── recordings/
#     └── MP4/
#         └── front_camera.mp4  # front camera
# ```

# %%
# Import required libraries
import json
import shutil
from pathlib import Path
from typing import Dict, List, Optional

import h5py
import pandas as pd
import numpy as np

# %% [markdown]
# ## Configuration
#
# Set paths and column names for the dataset CSV file.

# %%
# Configuration
BASE_PATH ="/home/michelmeyer/Dev/LeRobotLab"
CSV_FILE_PATH = BASE_PATH + "/csv/test-datasets-cristian.csv" 
LEROBOT_DOWNLOADS_DIRECTORY = BASE_PATH + "/downloaded_datasets"
OUTPUT_DATASETS_DIRECTORY = BASE_PATH + "/output_datasets/vjepa_layout"
VIDEO_KEY_COLUMN = "video_key"
DATASET_COLUMN = "dataset"

# Display configuration
print(f"CSV file path: {CSV_FILE_PATH}")
print(f"LeRobot datasets directory: {LEROBOT_DOWNLOADS_DIRECTORY}")
print(f"Output dataset path: {OUTPUT_DATASETS_DIRECTORY}")
print(f"CSV columns: {DATASET_COLUMN}, {VIDEO_KEY_COLUMN}")
# Out:
# CSV file path: /home/michelmeyer/Dev/LeRobotLab/csv/test-datasets-cristian.csv
# LeRobot datasets directory: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets
# Output dataset path: /home/michelmeyer/Dev/LeRobotLab/output_datasets/vjepa_layout
# CSV columns: dataset, video_key

# %% [markdown]
# ## Helper Functions
#
# We'll define several helper functions to process LeRobot datasets.

# %%
def load_dataset_info(dataset_path: Path) -> Dict:
    """Load dataset info from meta/info.json"""
    info_path = dataset_path / "meta" / "info.json"
    if not info_path.exists():
        raise FileNotFoundError(f"Dataset info file not found: {info_path}")

    with open(info_path, 'r') as f:
        return json.load(f)


def load_episode_data(dataset_path: Path, episode_idx: int) -> pd.DataFrame:
    """Load episode data from parquet file"""
    episode_file = dataset_path / "data" / "chunk-000" / f"episode_{episode_idx:06d}.parquet"
    if not episode_file.exists():
        raise FileNotFoundError(f"Episode file not found: {episode_file}")

    return pd.read_parquet(episode_file)


def create_trajectory_h5(episode_data: pd.DataFrame, output_path: Path):
    """Convert episode data to HDF5 trajectory format"""
    with h5py.File(output_path, 'w') as f:
        # Create groups for different data types
        action_group = f.create_group('action')
        observation_group = f.create_group('observation')
        metadata_group = f.create_group('metadata')

        # Save action data
        if 'action' in episode_data.columns:
            action_data = np.stack(episode_data['action'].values)
            action_group.create_dataset('data', data=action_data)
            
            # Add action names if available
            action_names = [
                "shoulder_pan.pos", "shoulder_lift.pos", "elbow_flex.pos",
                "wrist_flex.pos", "wrist_roll.pos", "gripper.pos"
            ]
            action_group.attrs['names'] = action_names

        # Save observation state data
        if 'observation.state' in episode_data.columns:
            obs_data = np.stack(episode_data['observation.state'].values)
            observation_group.create_dataset('state', data=obs_data)
            
            # Add state names
            state_names = [
                "shoulder_pan.pos", "shoulder_lift.pos", "elbow_flex.pos",
                "wrist_flex.pos", "wrist_roll.pos", "gripper.pos"
            ]
            observation_group.attrs['state_names'] = state_names

        # Save timestamps
        if 'timestamp' in episode_data.columns:
            timestamps = episode_data['timestamp'].values
            metadata_group.create_dataset('timestamp', data=timestamps)

        # Save frame indices
        if 'frame_index' in episode_data.columns:
            frame_indices = episode_data['frame_index'].values
            metadata_group.create_dataset('frame_index', data=frame_indices)

        # Add general metadata
        metadata_group.attrs['total_frames'] = len(episode_data)
        metadata_group.attrs['episode_length_s'] = len(episode_data) / 30.0  # Assuming 30fps
        metadata_group.attrs['fps'] = 30


def create_episode_metadata(episode_idx: int, episode_data: pd.DataFrame,
                          trajectory_path: Path, dataset_name: str) -> Dict:
    """Create metadata.json content for an episode"""
    metadata = {
        "episode_id": episode_idx,
        "episode_name": f"{dataset_name}-episode_{episode_idx:03d}",
        "source_dataset": dataset_name,
        "total_frames": len(episode_data),
        "duration_seconds": len(episode_data) / 30.0,  # Assuming 30fps
        "fps": 30,
        "files": {
            "trajectory": str(trajectory_path.name),
            "video": {
                "front_camera": str(Path("recordings/MP4/front_camera.mp4"))
            }
        },
        "data_keys": {
            "action": {
                "shape": [6],
                "dtype": "float32",
                "names": [
                    "shoulder_pan.pos", "shoulder_lift.pos", "elbow_flex.pos",
                    "wrist_flex.pos", "wrist_roll.pos", "gripper.pos"
                ]
            },
            "observation.state": {
                "shape": [6],
                "dtype": "float32", 
                "names": [
                    "shoulder_pan.pos", "shoulder_lift.pos", "elbow_flex.pos",
                    "wrist_flex.pos", "wrist_roll.pos", "gripper.pos"
                ]
            }
        },
        "task": "n/a"  # Based on the dataset
    }
    
    return metadata

# %% [markdown]
# ## Load Datasets from CSV
#
# First, we'll load dataset information from a CSV file.

# %%
def load_datasets_from_csv(csv_path, lerobot_dir=LEROBOT_DOWNLOADS_DIRECTORY, 
                         dataset_column=DATASET_COLUMN, 
                         video_key_column=VIDEO_KEY_COLUMN):
    """
    Load datasets information from a CSV file
    
    Args:
        csv_path: Path to the CSV file containing dataset info
        lerobot_dir: Base directory for downloaded datasets
        dataset_column: Name of column containing datasets in format "username/foldername"
        video_key_column: Name of column containing video key
        
    Returns:
        list: List of dataset configs and dict of video keys
    """
    try:
        # Load CSV file
        df = pd.read_csv(csv_path)
        print(f"Loaded CSV with {len(df)} rows")
        print(f"Columns: {list(df.columns)}")
        
        # Verify required columns exist
        if dataset_column not in df.columns:
            raise ValueError(f"Dataset column '{dataset_column}' not found in CSV")
        if video_key_column not in df.columns:
            raise ValueError(f"Video key column '{video_key_column}' not found in CSV")
            
        # Build dataset configs
        dataset_configs = []
        video_keys = {}
        
        for _, row in df.iterrows():
            dataset = row[dataset_column]
            video_key = row[video_key_column]
            
            # Parse username and foldername from dataset
            username, foldername = dataset.split('/')
            
            # Build dataset path
            dataset_path = Path(lerobot_dir) / username / foldername
            
            # Use full dataset name with '+' instead of '/' for folder naming
            display_name = dataset.replace('/', '+')
            
            dataset_config = {
                "name": display_name,  # Use username+foldername for episode naming
                "path": str(dataset_path),
                "username": username,
                "foldername": foldername,  # Store original foldername separately 
                "full_name": dataset
            }
            
            dataset_configs.append(dataset_config)
            video_keys[display_name] = f"observation.images.{video_key}"
            
        return dataset_configs, video_keys
        
    except Exception as e:
        print(f"Error loading CSV: {e}")
        return [], {}


# Load datasets from CSV
print(f"Loading datasets from CSV: {CSV_FILE_PATH}")
dataset_configs, video_keys = load_datasets_from_csv(CSV_FILE_PATH)

# Display dataset information
if dataset_configs:
    print(f"\nFound {len(dataset_configs)} datasets in CSV:")
    for config in dataset_configs:
        print(f"- {config['name']}: {config['path']}")
        print(f"  Video key: {video_keys.get(config['name'], 'unknown')}")
else:
    print("No datasets loaded from CSV.")
# Out:
# Loading datasets from CSV: /home/michelmeyer/Dev/LeRobotLab/csv/test-datasets-cristian.csv
# Loaded CSV with 4 rows
# Columns: ['dataset', 'video_key']
#
# Found 4 datasets in CSV:
# - 1lyz123576+so101_test: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/1lyz123576/so101_test
#   Video key: observation.images.phone
# - smanni+train_so100_all: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/smanni/train_so100_all
#   Video key: observation.images.intel_realsense
# - bjb7+so101_pen_touch_test_1: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/bjb7/so101_pen_touch_test_1
#   Video key: observation.images.camera_4
# - shreyasgite+so100_base_env: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/shreyasgite/so100_base_env
#   Video key: observation.images.laptop

# %% [markdown]
# ## Convert Datasets to VJEPA Layout
#
# Now, we'll convert the LeRobot datasets to the VJEPA layout.

# %%
def convert_datasets_to_vjepa(input_datasets: list, output_dataset_path: str, video_key: str = None):
    """Convert multiple LeRobot datasets to consolidated vjepa-format"""
    output_path = Path(output_dataset_path)
    
    print(f"Converting {len(input_datasets)} datasets to consolidated vjepa-format at {output_path}")
    
    # Create output directory structure
    output_path.mkdir(parents=True, exist_ok=True)
    episodes_dir = output_path / "episodes"
    episodes_dir.mkdir(exist_ok=True)
    
    # List to store episode paths for dataset_list.txt
    episode_paths = []
    total_episode_count = 0
    
    # Process each input dataset
    for dataset_config in input_datasets:
        dataset_name = dataset_config["name"]
        input_dataset_path = dataset_config["path"]
        # Use dataset-specific video key if provided
        current_video_key = dataset_config.get("video_key", video_key)
        if not current_video_key:
            print(f"Warning: No video key specified for dataset {dataset_name}. Skipping.")
            continue
            
        input_path = Path(input_dataset_path)
        
        if not input_path.exists():
            print(f"Warning: Input dataset not found: {input_path}")
            continue
            
        print(f"\nProcessing dataset '{dataset_name}' from {input_path}")
        
        # Load dataset info
        try:
            dataset_info = load_dataset_info(input_path)
        except Exception as e:
            print(f"Error loading dataset info for {dataset_name}: {e}")
            continue
        
        # Process each episode in this dataset
        videos_dir = input_path / "videos" / "chunk-000" / current_video_key
        dataset_episode_count = 0
        
        for episode_file in sorted((input_path / "data" / "chunk-000").glob("episode_*.parquet")):
            episode_idx = int(episode_file.stem.split('_')[1])
            dataset_episode_count += 1
            total_episode_count += 1
            
            print(f"  Processing episode {episode_idx}...")
            
            try:
                # Load episode data
                episode_data = load_episode_data(input_path, episode_idx)
                
                # Find corresponding video file
                video_path = videos_dir / f"episode_{episode_idx:06d}.mp4"
                
                if not video_path.exists():
                    print(f"    Warning: Video file not found: {video_path}")
                    continue
                
                # Create episode directory with dataset name prefix
                episode_dir_name = f"{dataset_name}-episode_{dataset_episode_count:03d}"
                episode_dir = episodes_dir / episode_dir_name
                episode_dir.mkdir(exist_ok=True)
                
                # Create recordings/MP4 directory
                recordings_dir = episode_dir / "recordings" / "MP4"
                recordings_dir.mkdir(parents=True, exist_ok=True)
                
                # Copy video file
                output_video_path = recordings_dir / "front_camera.mp4"
                shutil.copy2(video_path, output_video_path)
                
                # Create trajectory.h5
                trajectory_path = episode_dir / "trajectory.h5"
                create_trajectory_h5(episode_data, trajectory_path)
                
                # Create metadata.json
                metadata = create_episode_metadata(dataset_episode_count, episode_data,
                                                 trajectory_path, dataset_name)
                metadata_path = episode_dir / "metadata.json"
                with open(metadata_path, 'w') as f:
                    json.dump(metadata, f, indent=2)
                
                # Add to episode paths list
                episode_paths.append(f"episodes/{episode_dir_name}")
                
                print(f"    Created {episode_dir_name} with {len(episode_data)} frames")
                
            except Exception as e:
                print(f"    Error processing episode {episode_idx}: {e}")
                continue
        
        print(f"  Completed dataset '{dataset_name}': {dataset_episode_count} episodes")
    
    # Create dataset_list.txt - single file with all episodes
    dataset_list_path = output_path / "dataset_list.txt"
    with open(dataset_list_path, 'w') as f:
        for episode_path in episode_paths:
            f.write(f"{episode_path}\n")
    
    print(f"\nConsolidation complete!")
    print(f"Total episodes created: {total_episode_count}")
    print(f"Output directory: {output_path}")
    print(f"Dataset list saved to: {dataset_list_path}")
    
    return {
        "total_episodes": total_episode_count,
        "output_path": str(output_path),
        "dataset_list_path": str(dataset_list_path),
        "episode_paths": episode_paths
    }

# %% [markdown]
# ## Run Conversion Process
#
# Now let's run the full conversion process.

# %%
# Create consolidated output directory
output_path = Path(OUTPUT_DATASETS_DIRECTORY)
output_path.mkdir(parents=True, exist_ok=True)

# Process all datasets into a single consolidated output
all_dataset_configs = []

for dataset_config in dataset_configs:
    dataset_name = dataset_config["name"]
    video_key = video_keys.get(dataset_name, f"observation.images.{VIDEO_KEY_COLUMN}")
    
    print(f"Preparing dataset: {dataset_name}")
    print(f"  Path: {dataset_config['path']}")
    print(f"  Video key: {video_key}")
    
    # Store the video key in the dataset config for later use
    dataset_config["video_key"] = video_key
    all_dataset_configs.append(dataset_config)

# Convert all datasets at once to a single consolidated directory
print(f"\nConverting all datasets to consolidated directory: {output_path}")
result = convert_datasets_to_vjepa(all_dataset_configs, str(output_path))

print(f"All datasets consolidated into: {OUTPUT_DATASETS_DIRECTORY}")
# Out:
# Preparing dataset: 1lyz123576+so101_test
#   Path: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/1lyz123576/so101_test
#   Video key: observation.images.phone
# Preparing dataset: smanni+train_so100_all
#   Path: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/smanni/train_so100_all
#   Video key: observation.images.intel_realsense
# Preparing dataset: bjb7+so101_pen_touch_test_1
#   Path: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/bjb7/so101_pen_touch_test_1
#   Video key: observation.images.camera_4
# Preparing dataset: shreyasgite+so100_base_env
#   Path: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/shreyasgite/so100_base_env
#   Video key: observation.images.laptop
#
# Converting all datasets to consolidated directory: /home/michelmeyer/Dev/LeRobotLab/output_datasets/vjepa_layout
# Converting 4 datasets to consolidated vjepa-format at /home/michelmeyer/Dev/LeRobotLab/output_datasets/vjepa_layout
#
# Processing dataset '1lyz123576+so101_test' from /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/1lyz123576/so101_test
#   Processing episode 0...
#     Created 1lyz123576+so101_test-episode_001 with 548 frames
#   Processing episode 1...
#     Created 1lyz123576+so101_test-episode_002 with 538 frames
#   Processing episode 2...
#     Created 1lyz123576+so101_test-episode_003 with 548 frames
#   Processing episode 3...
#     Created 1lyz123576+so101_test-episode_004 with 487 frames
#   Processing episode 4...
#     Created 1lyz123576+so101_test-episode_005 with 465 frames
#   Processing episode 5...
#     Created 1lyz123576+so101_test-episode_006 with 652 frames
#   Processing episode 6...
#     Created 1lyz123576+so101_test-episode_007 with 605 frames
#   Processing episode 7...
#     Created 1lyz123576+so101_test-episode_008 with 616 frames
#   Processing episode 8...
#     Created 1lyz123576+so101_test-episode_009 with 589 frames
#   Processing episode 9...
#     Created 1lyz123576+so101_test-episode_010 with 532 frames
#   Processing episode 10...
#     Created 1lyz123576+so101_test-episode_011 with 639 frames
#   Processing episode 11...
#     Created 1lyz123576+so101_test-episode_012 with 706 frames
#   Processing episode 12...
#     Created 1lyz123576+so101_test-episode_013 with 487 frames
#   Processing episode 13...
#     Created 1lyz123576+so101_test-episode_014 with 474 frames
#   Processing episode 14...
#     Created 1lyz123576+so101_test-episode_015 with 544 frames
#   Processing episode 15...
#     Created 1lyz123576+so101_test-episode_016 with 542 frames
#   Processing episode 16...
#     Created 1lyz123576+so101_test-episode_017 with 552 frames
#   Processing episode 17...
#     Created 1lyz123576+so101_test-episode_018 with 590 frames
#   Processing episode 18...
#     Created 1lyz123576+so101_test-episode_019 with 505 frames
#   Processing episode 19...
#     Created 1lyz123576+so101_test-episode_020 with 434 frames
#   Processing episode 20...
#     Created 1lyz123576+so101_test-episode_021 with 509 frames
#   Processing episode 21...
#     Created 1lyz123576+so101_test-episode_022 with 636 frames
#   Processing episode 22...
#     Created 1lyz123576+so101_test-episode_023 with 498 frames
#   Processing episode 23...
#     Created 1lyz123576+so101_test-episode_024 with 547 frames
#   Processing episode 24...
#     Created 1lyz123576+so101_test-episode_025 with 505 frames
#   Processing episode 25...
#     Created 1lyz123576+so101_test-episode_026 with 591 frames
#   Processing episode 26...
#     Created 1lyz123576+so101_test-episode_027 with 510 frames
#   Processing episode 27...
#     Created 1lyz123576+so101_test-episode_028 with 641 frames
#   Processing episode 28...
#     Created 1lyz123576+so101_test-episode_029 with 507 frames
#   Processing episode 29...
#     Created 1lyz123576+so101_test-episode_030 with 489 frames
#   Processing episode 30...
#     Created 1lyz123576+so101_test-episode_031 with 444 frames
#   Processing episode 31...
#     Created 1lyz123576+so101_test-episode_032 with 521 frames
#   Processing episode 32...
#     Created 1lyz123576+so101_test-episode_033 with 552 frames
#   Processing episode 33...
#     Created 1lyz123576+so101_test-episode_034 with 533 frames
#   Processing episode 34...
#     Created 1lyz123576+so101_test-episode_035 with 481 frames
#   Processing episode 35...
#     Created 1lyz123576+so101_test-episode_036 with 498 frames
#   Processing episode 36...
#     Created 1lyz123576+so101_test-episode_037 with 571 frames
#   Processing episode 37...
#     Created 1lyz123576+so101_test-episode_038 with 520 frames
#   Processing episode 38...
#     Created 1lyz123576+so101_test-episode_039 with 550 frames
#   Processing episode 39...
#     Created 1lyz123576+so101_test-episode_040 with 624 frames
#   Processing episode 40...
#     Created 1lyz123576+so101_test-episode_041 with 455 frames
#   Processing episode 41...
#     Created 1lyz123576+so101_test-episode_042 with 509 frames
#   Processing episode 42...
#     Created 1lyz123576+so101_test-episode_043 with 510 frames
#   Processing episode 43...
#     Created 1lyz123576+so101_test-episode_044 with 635 frames
#   Processing episode 44...
#     Created 1lyz123576+so101_test-episode_045 with 422 frames
#   Processing episode 45...
#     Created 1lyz123576+so101_test-episode_046 with 569 frames
#   Processing episode 46...
#     Created 1lyz123576+so101_test-episode_047 with 463 frames
#   Processing episode 47...
#     Created 1lyz123576+so101_test-episode_048 with 479 frames
#   Processing episode 48...
#     Created 1lyz123576+so101_test-episode_049 with 432 frames
#   Processing episode 49...
#     Created 1lyz123576+so101_test-episode_050 with 582 frames
#   Processing episode 50...
#     Created 1lyz123576+so101_test-episode_051 with 485 frames
#   Processing episode 51...
#     Created 1lyz123576+so101_test-episode_052 with 541 frames
#   Processing episode 52...
#     Created 1lyz123576+so101_test-episode_053 with 471 frames
#   Processing episode 53...
#     Created 1lyz123576+so101_test-episode_054 with 543 frames
#   Processing episode 54...
#     Created 1lyz123576+so101_test-episode_055 with 518 frames
#   Processing episode 55...
#     Created 1lyz123576+so101_test-episode_056 with 583 frames
#   Processing episode 56...
#     Created 1lyz123576+so101_test-episode_057 with 649 frames
#   Processing episode 57...
#     Created 1lyz123576+so101_test-episode_058 with 458 frames
#   Processing episode 58...
#     Created 1lyz123576+so101_test-episode_059 with 496 frames
#   Processing episode 59...
#     Created 1lyz123576+so101_test-episode_060 with 473 frames
#   Processing episode 60...
#     Created 1lyz123576+so101_test-episode_061 with 425 frames
#   Processing episode 61...
#     Created 1lyz123576+so101_test-episode_062 with 482 frames
#   Processing episode 62...
#     Created 1lyz123576+so101_test-episode_063 with 457 frames
#   Processing episode 63...
#     Created 1lyz123576+so101_test-episode_064 with 429 frames
#   Processing episode 64...
#     Created 1lyz123576+so101_test-episode_065 with 467 frames
#   Processing episode 65...
#     Created 1lyz123576+so101_test-episode_066 with 472 frames
#   Processing episode 66...
#     Created 1lyz123576+so101_test-episode_067 with 522 frames
#   Processing episode 67...
#     Created 1lyz123576+so101_test-episode_068 with 385 frames
#   Processing episode 68...
#     Created 1lyz123576+so101_test-episode_069 with 599 frames
#   Processing episode 69...
#     Created 1lyz123576+so101_test-episode_070 with 424 frames
#   Processing episode 70...
#     Created 1lyz123576+so101_test-episode_071 with 425 frames
#   Processing episode 71...
#     Created 1lyz123576+so101_test-episode_072 with 384 frames
#   Processing episode 72...
#     Created 1lyz123576+so101_test-episode_073 with 395 frames
#   Processing episode 73...
#     Created 1lyz123576+so101_test-episode_074 with 474 frames
#   Processing episode 74...
#     Created 1lyz123576+so101_test-episode_075 with 512 frames
#   Processing episode 75...
#     Created 1lyz123576+so101_test-episode_076 with 486 frames
#   Processing episode 76...
#     Created 1lyz123576+so101_test-episode_077 with 463 frames
#   Processing episode 77...
#     Created 1lyz123576+so101_test-episode_078 with 410 frames
#   Processing episode 78...
#     Created 1lyz123576+so101_test-episode_079 with 391 frames
#   Processing episode 79...
#     Created 1lyz123576+so101_test-episode_080 with 429 frames
#   Processing episode 80...
#     Created 1lyz123576+so101_test-episode_081 with 464 frames
#   Processing episode 81...
#     Created 1lyz123576+so101_test-episode_082 with 435 frames
#   Processing episode 82...
#     Created 1lyz123576+so101_test-episode_083 with 437 frames
#   Processing episode 83...
#     Created 1lyz123576+so101_test-episode_084 with 451 frames
#   Processing episode 84...
#     Created 1lyz123576+so101_test-episode_085 with 431 frames
#   Processing episode 85...
#     Created 1lyz123576+so101_test-episode_086 with 470 frames
#   Processing episode 86...
#     Created 1lyz123576+so101_test-episode_087 with 458 frames
#   Processing episode 87...
#     Created 1lyz123576+so101_test-episode_088 with 497 frames
#   Processing episode 88...
#     Created 1lyz123576+so101_test-episode_089 with 467 frames
#   Processing episode 89...
#     Created 1lyz123576+so101_test-episode_090 with 441 frames
#   Processing episode 90...
#     Created 1lyz123576+so101_test-episode_091 with 626 frames
#   Processing episode 91...
#     Created 1lyz123576+so101_test-episode_092 with 401 frames
#   Processing episode 92...
#     Created 1lyz123576+so101_test-episode_093 with 440 frames
#   Processing episode 93...
#     Created 1lyz123576+so101_test-episode_094 with 579 frames
#   Processing episode 94...
#     Created 1lyz123576+so101_test-episode_095 with 894 frames
#   Processing episode 95...
#     Created 1lyz123576+so101_test-episode_096 with 504 frames
#   Processing episode 96...
#     Created 1lyz123576+so101_test-episode_097 with 527 frames
#   Processing episode 97...
#     Created 1lyz123576+so101_test-episode_098 with 470 frames
#   Processing episode 98...
#     Created 1lyz123576+so101_test-episode_099 with 490 frames
#   Processing episode 99...
#     Created 1lyz123576+so101_test-episode_100 with 545 frames
#   Processing episode 100...
#     Created 1lyz123576+so101_test-episode_101 with 446 frames
#   Processing episode 101...
#     Created 1lyz123576+so101_test-episode_102 with 433 frames
#   Processing episode 102...
#     Created 1lyz123576+so101_test-episode_103 with 409 frames
#   Processing episode 103...
#     Created 1lyz123576+so101_test-episode_104 with 391 frames
#   Processing episode 104...
#     Created 1lyz123576+so101_test-episode_105 with 337 frames
#   Processing episode 105...
#     Created 1lyz123576+so101_test-episode_106 with 392 frames
#   Processing episode 106...
#     Created 1lyz123576+so101_test-episode_107 with 383 frames
#   Processing episode 107...
#     Created 1lyz123576+so101_test-episode_108 with 371 frames
#   Processing episode 108...
#     Created 1lyz123576+so101_test-episode_109 with 355 frames
#   Processing episode 109...
#     Created 1lyz123576+so101_test-episode_110 with 356 frames
#   Processing episode 110...
#     Created 1lyz123576+so101_test-episode_111 with 421 frames
#   Processing episode 111...
#     Created 1lyz123576+so101_test-episode_112 with 405 frames
#   Processing episode 112...
#     Created 1lyz123576+so101_test-episode_113 with 367 frames
#   Processing episode 113...
#     Created 1lyz123576+so101_test-episode_114 with 392 frames
#   Processing episode 114...
#     Created 1lyz123576+so101_test-episode_115 with 347 frames
#   Processing episode 115...
#     Created 1lyz123576+so101_test-episode_116 with 363 frames
#   Processing episode 116...
#     Created 1lyz123576+so101_test-episode_117 with 342 frames
#   Processing episode 117...
#     Created 1lyz123576+so101_test-episode_118 with 379 frames
#   Processing episode 118...
#     Created 1lyz123576+so101_test-episode_119 with 389 frames
#   Processing episode 119...
#     Created 1lyz123576+so101_test-episode_120 with 377 frames
#   Processing episode 120...
#     Created 1lyz123576+so101_test-episode_121 with 609 frames
#   Processing episode 121...
#     Created 1lyz123576+so101_test-episode_122 with 372 frames
#   Processing episode 122...
#     Created 1lyz123576+so101_test-episode_123 with 393 frames
#   Processing episode 123...
#     Created 1lyz123576+so101_test-episode_124 with 287 frames
#   Processing episode 124...
#     Created 1lyz123576+so101_test-episode_125 with 425 frames
#   Processing episode 125...
#     Created 1lyz123576+so101_test-episode_126 with 323 frames
#   Processing episode 126...
#     Created 1lyz123576+so101_test-episode_127 with 603 frames
#   Processing episode 127...
#     Created 1lyz123576+so101_test-episode_128 with 479 frames
#   Processing episode 128...
#     Created 1lyz123576+so101_test-episode_129 with 453 frames
#   Processing episode 129...
#     Created 1lyz123576+so101_test-episode_130 with 211 frames
#   Processing episode 130...
#     Created 1lyz123576+so101_test-episode_131 with 309 frames
#   Processing episode 131...
#     Created 1lyz123576+so101_test-episode_132 with 325 frames
#   Processing episode 132...
#     Created 1lyz123576+so101_test-episode_133 with 302 frames
#   Processing episode 133...
#     Created 1lyz123576+so101_test-episode_134 with 331 frames
#   Processing episode 134...
#     Created 1lyz123576+so101_test-episode_135 with 317 frames
#   Completed dataset '1lyz123576+so101_test': 135 episodes
#
# Processing dataset 'smanni+train_so100_all' from /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/smanni/train_so100_all
#   Processing episode 0...
#     Created smanni+train_so100_all-episode_001 with 598 frames
#   Processing episode 1...
#     Created smanni+train_so100_all-episode_002 with 598 frames
#   Processing episode 2...
#     Created smanni+train_so100_all-episode_003 with 598 frames
#   Processing episode 3...
#     Created smanni+train_so100_all-episode_004 with 597 frames
#   Processing episode 4...
#     Created smanni+train_so100_all-episode_005 with 597 frames
#   Processing episode 5...
#     Created smanni+train_so100_all-episode_006 with 597 frames
#   Processing episode 6...
#     Created smanni+train_so100_all-episode_007 with 598 frames
#   Processing episode 7...
#     Created smanni+train_so100_all-episode_008 with 598 frames
#   Processing episode 8...
#     Created smanni+train_so100_all-episode_009 with 598 frames
#   Processing episode 9...
#     Created smanni+train_so100_all-episode_010 with 598 frames
#   Processing episode 10...
#     Created smanni+train_so100_all-episode_011 with 597 frames
#   Processing episode 11...
#     Created smanni+train_so100_all-episode_012 with 598 frames
#   Processing episode 12...
#     Created smanni+train_so100_all-episode_013 with 597 frames
#   Processing episode 13...
#     Created smanni+train_so100_all-episode_014 with 597 frames
#   Processing episode 14...
#     Created smanni+train_so100_all-episode_015 with 597 frames
#   Processing episode 15...
#     Created smanni+train_so100_all-episode_016 with 597 frames
#   Processing episode 16...
#     Created smanni+train_so100_all-episode_017 with 598 frames
#   Processing episode 17...
#     Created smanni+train_so100_all-episode_018 with 598 frames
#   Processing episode 18...
#     Created smanni+train_so100_all-episode_019 with 598 frames
#   Processing episode 19...
#     Created smanni+train_so100_all-episode_020 with 598 frames
#   Processing episode 20...
#     Created smanni+train_so100_all-episode_021 with 597 frames
#   Processing episode 21...
#     Created smanni+train_so100_all-episode_022 with 597 frames
#   Processing episode 22...
#     Created smanni+train_so100_all-episode_023 with 597 frames
#   Processing episode 23...
#     Created smanni+train_so100_all-episode_024 with 597 frames
#   Processing episode 24...
#     Created smanni+train_so100_all-episode_025 with 598 frames
#   Processing episode 25...
#     Created smanni+train_so100_all-episode_026 with 597 frames
#   Processing episode 26...
#     Created smanni+train_so100_all-episode_027 with 597 frames
#   Processing episode 27...
#     Created smanni+train_so100_all-episode_028 with 597 frames
#   Processing episode 28...
#     Created smanni+train_so100_all-episode_029 with 597 frames
#   Processing episode 29...
#     Created smanni+train_so100_all-episode_030 with 597 frames
#   Processing episode 30...
#     Created smanni+train_so100_all-episode_031 with 597 frames
#   Processing episode 31...
#     Created smanni+train_so100_all-episode_032 with 597 frames
#   Processing episode 32...
#     Created smanni+train_so100_all-episode_033 with 598 frames
#   Processing episode 33...
#     Created smanni+train_so100_all-episode_034 with 598 frames
#   Processing episode 34...
#     Created smanni+train_so100_all-episode_035 with 597 frames
#   Processing episode 35...
#     Created smanni+train_so100_all-episode_036 with 597 frames
#   Processing episode 36...
#     Created smanni+train_so100_all-episode_037 with 597 frames
#   Processing episode 37...
#     Created smanni+train_so100_all-episode_038 with 597 frames
#   Processing episode 38...
#     Created smanni+train_so100_all-episode_039 with 598 frames
#   Processing episode 39...
#     Created smanni+train_so100_all-episode_040 with 597 frames
#   Processing episode 40...
#     Created smanni+train_so100_all-episode_041 with 597 frames
#   Processing episode 41...
#     Created smanni+train_so100_all-episode_042 with 597 frames
#   Processing episode 42...
#     Created smanni+train_so100_all-episode_043 with 597 frames
#   Processing episode 43...
#     Created smanni+train_so100_all-episode_044 with 598 frames
#   Processing episode 44...
#     Created smanni+train_so100_all-episode_045 with 597 frames
#   Processing episode 45...
#     Created smanni+train_so100_all-episode_046 with 598 frames
#   Processing episode 46...
#     Created smanni+train_so100_all-episode_047 with 597 frames
#   Processing episode 47...
#     Created smanni+train_so100_all-episode_048 with 597 frames
#   Processing episode 48...
#     Created smanni+train_so100_all-episode_049 with 598 frames
#   Processing episode 49...
#     Created smanni+train_so100_all-episode_050 with 597 frames
#   Processing episode 50...
#     Created smanni+train_so100_all-episode_051 with 597 frames
#   Processing episode 51...
#     Created smanni+train_so100_all-episode_052 with 598 frames
#   Processing episode 52...
#     Created smanni+train_so100_all-episode_053 with 597 frames
#   Processing episode 53...
#     Created smanni+train_so100_all-episode_054 with 598 frames
#   Processing episode 54...
#     Created smanni+train_so100_all-episode_055 with 597 frames
#   Processing episode 55...
#     Created smanni+train_so100_all-episode_056 with 597 frames
#   Processing episode 56...
#     Created smanni+train_so100_all-episode_057 with 597 frames
#   Processing episode 57...
#     Created smanni+train_so100_all-episode_058 with 597 frames
#   Processing episode 58...
#     Created smanni+train_so100_all-episode_059 with 597 frames
#   Processing episode 59...
#     Created smanni+train_so100_all-episode_060 with 598 frames
#   Processing episode 60...
#     Created smanni+train_so100_all-episode_061 with 597 frames
#   Processing episode 61...
#     Created smanni+train_so100_all-episode_062 with 597 frames
#   Processing episode 62...
#     Created smanni+train_so100_all-episode_063 with 597 frames
#   Processing episode 63...
#     Created smanni+train_so100_all-episode_064 with 597 frames
#   Processing episode 64...
#     Created smanni+train_so100_all-episode_065 with 597 frames
#   Processing episode 65...
#     Created smanni+train_so100_all-episode_066 with 598 frames
#   Processing episode 66...
#     Created smanni+train_so100_all-episode_067 with 598 frames
#   Processing episode 67...
#     Created smanni+train_so100_all-episode_068 with 598 frames
#   Processing episode 68...
#     Created smanni+train_so100_all-episode_069 with 597 frames
#   Processing episode 69...
#     Created smanni+train_so100_all-episode_070 with 597 frames
#   Processing episode 70...
#     Created smanni+train_so100_all-episode_071 with 597 frames
#   Processing episode 71...
#     Created smanni+train_so100_all-episode_072 with 597 frames
#   Processing episode 72...
#     Created smanni+train_so100_all-episode_073 with 598 frames
#   Processing episode 73...
#     Created smanni+train_so100_all-episode_074 with 597 frames
#   Processing episode 74...
#     Created smanni+train_so100_all-episode_075 with 597 frames
#   Processing episode 75...
#     Created smanni+train_so100_all-episode_076 with 598 frames
#   Processing episode 76...
#     Created smanni+train_so100_all-episode_077 with 597 frames
#   Processing episode 77...
#     Created smanni+train_so100_all-episode_078 with 597 frames
#   Processing episode 78...
#     Created smanni+train_so100_all-episode_079 with 597 frames
#   Processing episode 79...
#     Created smanni+train_so100_all-episode_080 with 598 frames
#   Processing episode 80...
#     Created smanni+train_so100_all-episode_081 with 597 frames
#   Processing episode 81...
#     Created smanni+train_so100_all-episode_082 with 597 frames
#   Processing episode 82...
#     Created smanni+train_so100_all-episode_083 with 598 frames
#   Processing episode 83...
#     Created smanni+train_so100_all-episode_084 with 597 frames
#   Processing episode 84...
#     Created smanni+train_so100_all-episode_085 with 597 frames
#   Processing episode 85...
#     Created smanni+train_so100_all-episode_086 with 597 frames
#   Processing episode 86...
#     Created smanni+train_so100_all-episode_087 with 597 frames
#   Processing episode 87...
#     Created smanni+train_so100_all-episode_088 with 597 frames
#   Processing episode 88...
#     Created smanni+train_so100_all-episode_089 with 597 frames
#   Processing episode 89...
#     Created smanni+train_so100_all-episode_090 with 597 frames
#   Processing episode 90...
#     Created smanni+train_so100_all-episode_091 with 598 frames
#   Processing episode 91...
#     Created smanni+train_so100_all-episode_092 with 597 frames
#   Processing episode 92...
#     Created smanni+train_so100_all-episode_093 with 597 frames
#   Processing episode 93...
#     Created smanni+train_so100_all-episode_094 with 597 frames
#   Processing episode 94...
#     Created smanni+train_so100_all-episode_095 with 597 frames
#   Processing episode 95...
#     Created smanni+train_so100_all-episode_096 with 597 frames
#   Processing episode 96...
#     Created smanni+train_so100_all-episode_097 with 598 frames
#   Processing episode 97...
#     Created smanni+train_so100_all-episode_098 with 597 frames
#   Processing episode 98...
#     Created smanni+train_so100_all-episode_099 with 597 frames
#   Processing episode 99...
#     Created smanni+train_so100_all-episode_100 with 597 frames
#   Processing episode 100...
#     Created smanni+train_so100_all-episode_101 with 358 frames
#   Processing episode 101...
#     Created smanni+train_so100_all-episode_102 with 359 frames
#   Processing episode 102...
#     Created smanni+train_so100_all-episode_103 with 359 frames
#   Processing episode 103...
#     Created smanni+train_so100_all-episode_104 with 359 frames
#   Processing episode 104...
#     Created smanni+train_so100_all-episode_105 with 358 frames
#   Processing episode 105...
#     Created smanni+train_so100_all-episode_106 with 359 frames
#   Processing episode 106...
#     Created smanni+train_so100_all-episode_107 with 359 frames
#   Processing episode 107...
#     Created smanni+train_so100_all-episode_108 with 358 frames
#   Processing episode 108...
#     Created smanni+train_so100_all-episode_109 with 359 frames
#   Processing episode 109...
#     Created smanni+train_so100_all-episode_110 with 358 frames
#   Processing episode 110...
#     Created smanni+train_so100_all-episode_111 with 359 frames
#   Processing episode 111...
#     Created smanni+train_so100_all-episode_112 with 359 frames
#   Processing episode 112...
#     Created smanni+train_so100_all-episode_113 with 359 frames
#   Processing episode 113...
#     Created smanni+train_so100_all-episode_114 with 358 frames
#   Processing episode 114...
#     Created smanni+train_so100_all-episode_115 with 358 frames
#   Processing episode 115...
#     Created smanni+train_so100_all-episode_116 with 359 frames
#   Processing episode 116...
#     Created smanni+train_so100_all-episode_117 with 359 frames
#   Processing episode 117...
#     Created smanni+train_so100_all-episode_118 with 359 frames
#   Processing episode 118...
#     Created smanni+train_so100_all-episode_119 with 359 frames
#   Processing episode 119...
#     Created smanni+train_so100_all-episode_120 with 359 frames
#   Processing episode 120...
#     Created smanni+train_so100_all-episode_121 with 359 frames
#   Processing episode 121...
#     Created smanni+train_so100_all-episode_122 with 358 frames
#   Processing episode 122...
#     Created smanni+train_so100_all-episode_123 with 358 frames
#   Processing episode 123...
#     Created smanni+train_so100_all-episode_124 with 358 frames
#   Processing episode 124...
#     Created smanni+train_so100_all-episode_125 with 358 frames
#   Processing episode 125...
#     Created smanni+train_so100_all-episode_126 with 358 frames
#   Processing episode 126...
#     Created smanni+train_so100_all-episode_127 with 358 frames
#   Processing episode 127...
#     Created smanni+train_so100_all-episode_128 with 359 frames
#   Processing episode 128...
#     Created smanni+train_so100_all-episode_129 with 359 frames
#   Processing episode 129...
#     Created smanni+train_so100_all-episode_130 with 358 frames
#   Processing episode 130...
#     Created smanni+train_so100_all-episode_131 with 358 frames
#   Processing episode 131...
#     Created smanni+train_so100_all-episode_132 with 358 frames
#   Processing episode 132...
#     Created smanni+train_so100_all-episode_133 with 358 frames
#   Processing episode 133...
#     Created smanni+train_so100_all-episode_134 with 358 frames
#   Processing episode 134...
#     Created smanni+train_so100_all-episode_135 with 358 frames
#   Processing episode 135...
#     Created smanni+train_so100_all-episode_136 with 358 frames
#   Processing episode 136...
#     Created smanni+train_so100_all-episode_137 with 358 frames
#   Processing episode 137...
#     Created smanni+train_so100_all-episode_138 with 358 frames
#   Processing episode 138...
#     Created smanni+train_so100_all-episode_139 with 359 frames
#   Processing episode 139...
#     Created smanni+train_so100_all-episode_140 with 358 frames
#   Processing episode 140...
#     Created smanni+train_so100_all-episode_141 with 359 frames
#   Processing episode 141...
#     Created smanni+train_so100_all-episode_142 with 358 frames
#   Processing episode 142...
#     Created smanni+train_so100_all-episode_143 with 359 frames
#   Processing episode 143...
#     Created smanni+train_so100_all-episode_144 with 358 frames
#   Processing episode 144...
#     Created smanni+train_so100_all-episode_145 with 359 frames
#   Processing episode 145...
#     Created smanni+train_so100_all-episode_146 with 359 frames
#   Processing episode 146...
#     Created smanni+train_so100_all-episode_147 with 358 frames
#   Processing episode 147...
#     Created smanni+train_so100_all-episode_148 with 359 frames
#   Processing episode 148...
#     Created smanni+train_so100_all-episode_149 with 358 frames
#   Processing episode 149...
#     Created smanni+train_so100_all-episode_150 with 359 frames
#   Processing episode 150...
#     Created smanni+train_so100_all-episode_151 with 538 frames
#   Processing episode 151...
#     Created smanni+train_so100_all-episode_152 with 538 frames
#   Processing episode 152...
#     Created smanni+train_so100_all-episode_153 with 538 frames
#   Processing episode 153...
#     Created smanni+train_so100_all-episode_154 with 538 frames
#   Processing episode 154...
#     Created smanni+train_so100_all-episode_155 with 538 frames
#   Processing episode 155...
#     Created smanni+train_so100_all-episode_156 with 538 frames
#   Processing episode 156...
#     Created smanni+train_so100_all-episode_157 with 538 frames
#   Processing episode 157...
#     Created smanni+train_so100_all-episode_158 with 538 frames
#   Processing episode 158...
#     Created smanni+train_so100_all-episode_159 with 538 frames
#   Processing episode 159...
#     Created smanni+train_so100_all-episode_160 with 538 frames
#   Processing episode 160...
#     Created smanni+train_so100_all-episode_161 with 538 frames
#   Processing episode 161...
#     Created smanni+train_so100_all-episode_162 with 537 frames
#   Processing episode 162...
#     Created smanni+train_so100_all-episode_163 with 538 frames
#   Processing episode 163...
#     Created smanni+train_so100_all-episode_164 with 538 frames
#   Processing episode 164...
#     Created smanni+train_so100_all-episode_165 with 538 frames
#   Processing episode 165...
#     Created smanni+train_so100_all-episode_166 with 538 frames
#   Processing episode 166...
#     Created smanni+train_so100_all-episode_167 with 538 frames
#   Processing episode 167...
#     Created smanni+train_so100_all-episode_168 with 538 frames
#   Processing episode 168...
#     Created smanni+train_so100_all-episode_169 with 538 frames
#   Processing episode 169...
#     Created smanni+train_so100_all-episode_170 with 538 frames
#   Processing episode 170...
#     Created smanni+train_so100_all-episode_171 with 538 frames
#   Processing episode 171...
#     Created smanni+train_so100_all-episode_172 with 537 frames
#   Processing episode 172...
#     Created smanni+train_so100_all-episode_173 with 538 frames
#   Processing episode 173...
#     Created smanni+train_so100_all-episode_174 with 538 frames
#   Processing episode 174...
#     Created smanni+train_so100_all-episode_175 with 538 frames
#   Processing episode 175...
#     Created smanni+train_so100_all-episode_176 with 538 frames
#   Processing episode 176...
#     Created smanni+train_so100_all-episode_177 with 538 frames
#   Processing episode 177...
#     Created smanni+train_so100_all-episode_178 with 538 frames
#   Processing episode 178...
#     Created smanni+train_so100_all-episode_179 with 538 frames
#   Processing episode 179...
#     Created smanni+train_so100_all-episode_180 with 538 frames
#   Processing episode 180...
#     Created smanni+train_so100_all-episode_181 with 538 frames
#   Processing episode 181...
#     Created smanni+train_so100_all-episode_182 with 538 frames
#   Processing episode 182...
#     Created smanni+train_so100_all-episode_183 with 538 frames
#   Processing episode 183...
#     Created smanni+train_so100_all-episode_184 with 538 frames
#   Processing episode 184...
#     Created smanni+train_so100_all-episode_185 with 538 frames
#   Processing episode 185...
#     Created smanni+train_so100_all-episode_186 with 538 frames
#   Processing episode 186...
#     Created smanni+train_so100_all-episode_187 with 538 frames
#   Processing episode 187...
#     Created smanni+train_so100_all-episode_188 with 538 frames
#   Processing episode 188...
#     Created smanni+train_so100_all-episode_189 with 538 frames
#   Processing episode 189...
#     Created smanni+train_so100_all-episode_190 with 538 frames
#   Processing episode 190...
#     Created smanni+train_so100_all-episode_191 with 538 frames
#   Processing episode 191...
#     Created smanni+train_so100_all-episode_192 with 538 frames
#   Processing episode 192...
#     Created smanni+train_so100_all-episode_193 with 538 frames
#   Processing episode 193...
#     Created smanni+train_so100_all-episode_194 with 538 frames
#   Processing episode 194...
#     Created smanni+train_so100_all-episode_195 with 538 frames
#   Processing episode 195...
#     Created smanni+train_so100_all-episode_196 with 538 frames
#   Processing episode 196...
#     Created smanni+train_so100_all-episode_197 with 538 frames
#   Processing episode 197...
#     Created smanni+train_so100_all-episode_198 with 538 frames
#   Processing episode 198...
#     Created smanni+train_so100_all-episode_199 with 538 frames
#   Processing episode 199...
#     Created smanni+train_so100_all-episode_200 with 538 frames
#   Processing episode 200...
#     Created smanni+train_so100_all-episode_201 with 597 frames
#   Processing episode 201...
#     Created smanni+train_so100_all-episode_202 with 597 frames
#   Processing episode 202...
#     Created smanni+train_so100_all-episode_203 with 597 frames
#   Processing episode 203...
#     Created smanni+train_so100_all-episode_204 with 597 frames
#   Processing episode 204...
#     Created smanni+train_so100_all-episode_205 with 597 frames
#   Processing episode 205...
#     Created smanni+train_so100_all-episode_206 with 597 frames
#   Processing episode 206...
#     Created smanni+train_so100_all-episode_207 with 597 frames
#   Processing episode 207...
#     Created smanni+train_so100_all-episode_208 with 597 frames
#   Processing episode 208...
#     Created smanni+train_so100_all-episode_209 with 597 frames
#   Processing episode 209...
#     Created smanni+train_so100_all-episode_210 with 597 frames
#   Processing episode 210...
#     Created smanni+train_so100_all-episode_211 with 597 frames
#   Processing episode 211...
#     Created smanni+train_so100_all-episode_212 with 597 frames
#   Processing episode 212...
#     Created smanni+train_so100_all-episode_213 with 597 frames
#   Processing episode 213...
#     Created smanni+train_so100_all-episode_214 with 597 frames
#   Processing episode 214...
#     Created smanni+train_so100_all-episode_215 with 597 frames
#   Processing episode 215...
#     Created smanni+train_so100_all-episode_216 with 597 frames
#   Processing episode 216...
#     Created smanni+train_so100_all-episode_217 with 597 frames
#   Processing episode 217...
#     Created smanni+train_so100_all-episode_218 with 597 frames
#   Processing episode 218...
#     Created smanni+train_so100_all-episode_219 with 597 frames
#   Processing episode 219...
#     Created smanni+train_so100_all-episode_220 with 597 frames
#   Processing episode 220...
#     Created smanni+train_so100_all-episode_221 with 597 frames
#   Processing episode 221...
#     Created smanni+train_so100_all-episode_222 with 597 frames
#   Processing episode 222...
#     Created smanni+train_so100_all-episode_223 with 597 frames
#   Processing episode 223...
#     Created smanni+train_so100_all-episode_224 with 597 frames
#   Processing episode 224...
#     Created smanni+train_so100_all-episode_225 with 597 frames
#   Processing episode 225...
#     Created smanni+train_so100_all-episode_226 with 597 frames
#   Processing episode 226...
#     Created smanni+train_so100_all-episode_227 with 597 frames
#   Processing episode 227...
#     Created smanni+train_so100_all-episode_228 with 597 frames
#   Processing episode 228...
#     Created smanni+train_so100_all-episode_229 with 597 frames
#   Processing episode 229...
#     Created smanni+train_so100_all-episode_230 with 597 frames
#   Processing episode 230...
#     Created smanni+train_so100_all-episode_231 with 597 frames
#   Processing episode 231...
#     Created smanni+train_so100_all-episode_232 with 597 frames
#   Processing episode 232...
#     Created smanni+train_so100_all-episode_233 with 597 frames
#   Processing episode 233...
#     Created smanni+train_so100_all-episode_234 with 597 frames
#   Processing episode 234...
#     Created smanni+train_so100_all-episode_235 with 597 frames
#   Processing episode 235...
#     Created smanni+train_so100_all-episode_236 with 597 frames
#   Processing episode 236...
#     Created smanni+train_so100_all-episode_237 with 597 frames
#   Processing episode 237...
#     Created smanni+train_so100_all-episode_238 with 597 frames
#   Processing episode 238...
#     Created smanni+train_so100_all-episode_239 with 597 frames
#   Processing episode 239...
#     Created smanni+train_so100_all-episode_240 with 597 frames
#   Processing episode 240...
#     Created smanni+train_so100_all-episode_241 with 597 frames
#   Processing episode 241...
#     Created smanni+train_so100_all-episode_242 with 597 frames
#   Processing episode 242...
#     Created smanni+train_so100_all-episode_243 with 597 frames
#   Processing episode 243...
#     Created smanni+train_so100_all-episode_244 with 597 frames
#   Processing episode 244...
#     Created smanni+train_so100_all-episode_245 with 597 frames
#   Processing episode 245...
#     Created smanni+train_so100_all-episode_246 with 597 frames
#   Processing episode 246...
#     Created smanni+train_so100_all-episode_247 with 597 frames
#   Processing episode 247...
#     Created smanni+train_so100_all-episode_248 with 597 frames
#   Processing episode 248...
#     Created smanni+train_so100_all-episode_249 with 597 frames
#   Processing episode 249...
#     Created smanni+train_so100_all-episode_250 with 597 frames
#   Processing episode 250...
#     Created smanni+train_so100_all-episode_251 with 896 frames
#   Processing episode 251...
#     Created smanni+train_so100_all-episode_252 with 896 frames
#   Processing episode 252...
#     Created smanni+train_so100_all-episode_253 with 896 frames
#   Processing episode 253...
#     Created smanni+train_so100_all-episode_254 with 896 frames
#   Processing episode 254...
#     Created smanni+train_so100_all-episode_255 with 896 frames
#   Processing episode 255...
#     Created smanni+train_so100_all-episode_256 with 896 frames
#   Processing episode 256...
#     Created smanni+train_so100_all-episode_257 with 896 frames
#   Processing episode 257...
#     Created smanni+train_so100_all-episode_258 with 896 frames
#   Processing episode 258...
#     Created smanni+train_so100_all-episode_259 with 896 frames
#   Processing episode 259...
#     Created smanni+train_so100_all-episode_260 with 896 frames
#   Processing episode 260...
#     Created smanni+train_so100_all-episode_261 with 896 frames
#   Processing episode 261...
#     Created smanni+train_so100_all-episode_262 with 896 frames
#   Processing episode 262...
#     Created smanni+train_so100_all-episode_263 with 896 frames
#   Processing episode 263...
#     Created smanni+train_so100_all-episode_264 with 896 frames
#   Processing episode 264...
#     Created smanni+train_so100_all-episode_265 with 896 frames
#   Processing episode 265...
#     Created smanni+train_so100_all-episode_266 with 896 frames
#   Processing episode 266...
#     Created smanni+train_so100_all-episode_267 with 896 frames
#   Processing episode 267...
#     Created smanni+train_so100_all-episode_268 with 896 frames
#   Processing episode 268...
#     Created smanni+train_so100_all-episode_269 with 896 frames
#   Processing episode 269...
#     Created smanni+train_so100_all-episode_270 with 896 frames
#   Processing episode 270...
#     Created smanni+train_so100_all-episode_271 with 896 frames
#   Processing episode 271...
#     Created smanni+train_so100_all-episode_272 with 896 frames
#   Processing episode 272...
#     Created smanni+train_so100_all-episode_273 with 896 frames
#   Processing episode 273...
#     Created smanni+train_so100_all-episode_274 with 896 frames
#   Processing episode 274...
#     Created smanni+train_so100_all-episode_275 with 896 frames
#   Processing episode 275...
#     Created smanni+train_so100_all-episode_276 with 896 frames
#   Processing episode 276...
#     Created smanni+train_so100_all-episode_277 with 896 frames
#   Processing episode 277...
#     Created smanni+train_so100_all-episode_278 with 896 frames
#   Processing episode 278...
#     Created smanni+train_so100_all-episode_279 with 896 frames
#   Processing episode 279...
#     Created smanni+train_so100_all-episode_280 with 896 frames
#   Processing episode 280...
#     Created smanni+train_so100_all-episode_281 with 896 frames
#   Processing episode 281...
#     Created smanni+train_so100_all-episode_282 with 896 frames
#   Processing episode 282...
#     Created smanni+train_so100_all-episode_283 with 896 frames
#   Processing episode 283...
#     Created smanni+train_so100_all-episode_284 with 896 frames
#   Processing episode 284...
#     Created smanni+train_so100_all-episode_285 with 896 frames
#   Processing episode 285...
#     Created smanni+train_so100_all-episode_286 with 896 frames
#   Processing episode 286...
#     Created smanni+train_so100_all-episode_287 with 896 frames
#   Processing episode 287...
#     Created smanni+train_so100_all-episode_288 with 896 frames
#   Processing episode 288...
#     Created smanni+train_so100_all-episode_289 with 895 frames
#   Processing episode 289...
#     Created smanni+train_so100_all-episode_290 with 896 frames
#   Processing episode 290...
#     Created smanni+train_so100_all-episode_291 with 895 frames
#   Processing episode 291...
#     Created smanni+train_so100_all-episode_292 with 896 frames
#   Processing episode 292...
#     Created smanni+train_so100_all-episode_293 with 896 frames
#   Processing episode 293...
#     Created smanni+train_so100_all-episode_294 with 896 frames
#   Processing episode 294...
#     Created smanni+train_so100_all-episode_295 with 896 frames
#   Processing episode 295...
#     Created smanni+train_so100_all-episode_296 with 896 frames
#   Processing episode 296...
#     Created smanni+train_so100_all-episode_297 with 896 frames
#   Processing episode 297...
#     Created smanni+train_so100_all-episode_298 with 896 frames
#   Processing episode 298...
#     Created smanni+train_so100_all-episode_299 with 896 frames
#   Processing episode 299...
#     Created smanni+train_so100_all-episode_300 with 895 frames
#   Processing episode 300...
#     Created smanni+train_so100_all-episode_301 with 895 frames
#   Processing episode 301...
#     Created smanni+train_so100_all-episode_302 with 896 frames
#   Processing episode 302...
#     Created smanni+train_so100_all-episode_303 with 896 frames
#   Processing episode 303...
#     Created smanni+train_so100_all-episode_304 with 896 frames
#   Processing episode 304...
#     Created smanni+train_so100_all-episode_305 with 896 frames
#   Processing episode 305...
#     Created smanni+train_so100_all-episode_306 with 896 frames
#   Processing episode 306...
#     Created smanni+train_so100_all-episode_307 with 896 frames
#   Processing episode 307...
#     Created smanni+train_so100_all-episode_308 with 896 frames
#   Processing episode 308...
#     Created smanni+train_so100_all-episode_309 with 896 frames
#   Processing episode 309...
#     Created smanni+train_so100_all-episode_310 with 896 frames
#   Processing episode 310...
#     Created smanni+train_so100_all-episode_311 with 896 frames
#   Processing episode 311...
#     Created smanni+train_so100_all-episode_312 with 895 frames
#   Processing episode 312...
#     Created smanni+train_so100_all-episode_313 with 896 frames
#   Processing episode 313...
#     Created smanni+train_so100_all-episode_314 with 896 frames
#   Processing episode 314...
#     Created smanni+train_so100_all-episode_315 with 896 frames
#   Processing episode 315...
#     Created smanni+train_so100_all-episode_316 with 896 frames
#   Processing episode 316...
#     Created smanni+train_so100_all-episode_317 with 896 frames
#   Processing episode 317...
#     Created smanni+train_so100_all-episode_318 with 896 frames
#   Processing episode 318...
#     Created smanni+train_so100_all-episode_319 with 896 frames
#   Processing episode 319...
#     Created smanni+train_so100_all-episode_320 with 896 frames
#   Processing episode 320...
#     Created smanni+train_so100_all-episode_321 with 896 frames
#   Processing episode 321...
#     Created smanni+train_so100_all-episode_322 with 896 frames
#   Processing episode 322...
#     Created smanni+train_so100_all-episode_323 with 896 frames
#   Processing episode 323...
#     Created smanni+train_so100_all-episode_324 with 896 frames
#   Processing episode 324...
#     Created smanni+train_so100_all-episode_325 with 896 frames
#   Processing episode 325...
#     Created smanni+train_so100_all-episode_326 with 896 frames
#   Processing episode 326...
#     Created smanni+train_so100_all-episode_327 with 896 frames
#   Processing episode 327...
#     Created smanni+train_so100_all-episode_328 with 895 frames
#   Processing episode 328...
#     Created smanni+train_so100_all-episode_329 with 896 frames
#   Processing episode 329...
#     Created smanni+train_so100_all-episode_330 with 896 frames
#   Processing episode 330...
#     Created smanni+train_so100_all-episode_331 with 896 frames
#   Processing episode 331...
#     Created smanni+train_so100_all-episode_332 with 896 frames
#   Processing episode 332...
#     Created smanni+train_so100_all-episode_333 with 896 frames
#   Processing episode 333...
#     Created smanni+train_so100_all-episode_334 with 896 frames
#   Processing episode 334...
#     Created smanni+train_so100_all-episode_335 with 896 frames
#   Processing episode 335...
#     Created smanni+train_so100_all-episode_336 with 896 frames
#   Processing episode 336...
#     Created smanni+train_so100_all-episode_337 with 896 frames
#   Processing episode 337...
#     Created smanni+train_so100_all-episode_338 with 896 frames
#   Processing episode 338...
#     Created smanni+train_so100_all-episode_339 with 896 frames
#   Processing episode 339...
#     Created smanni+train_so100_all-episode_340 with 896 frames
#   Processing episode 340...
#     Created smanni+train_so100_all-episode_341 with 896 frames
#   Processing episode 341...
#     Created smanni+train_so100_all-episode_342 with 896 frames
#   Processing episode 342...
#     Created smanni+train_so100_all-episode_343 with 896 frames
#   Processing episode 343...
#     Created smanni+train_so100_all-episode_344 with 896 frames
#   Processing episode 344...
#     Created smanni+train_so100_all-episode_345 with 895 frames
#   Processing episode 345...
#     Created smanni+train_so100_all-episode_346 with 896 frames
#   Processing episode 346...
#     Created smanni+train_so100_all-episode_347 with 896 frames
#   Processing episode 347...
#     Created smanni+train_so100_all-episode_348 with 896 frames
#   Processing episode 348...
#     Created smanni+train_so100_all-episode_349 with 896 frames
#   Processing episode 349...
#     Created smanni+train_so100_all-episode_350 with 896 frames
#   Processing episode 350...
#     Created smanni+train_so100_all-episode_351 with 597 frames
#   Processing episode 351...
#     Created smanni+train_so100_all-episode_352 with 598 frames
#   Processing episode 352...
#     Created smanni+train_so100_all-episode_353 with 597 frames
#   Processing episode 353...
#     Created smanni+train_so100_all-episode_354 with 597 frames
#   Processing episode 354...
#     Created smanni+train_so100_all-episode_355 with 597 frames
#   Processing episode 355...
#     Created smanni+train_so100_all-episode_356 with 597 frames
#   Processing episode 356...
#     Created smanni+train_so100_all-episode_357 with 597 frames
#   Processing episode 357...
#     Created smanni+train_so100_all-episode_358 with 597 frames
#   Processing episode 358...
#     Created smanni+train_so100_all-episode_359 with 597 frames
#   Processing episode 359...
#     Created smanni+train_so100_all-episode_360 with 597 frames
#   Processing episode 360...
#     Created smanni+train_so100_all-episode_361 with 597 frames
#   Processing episode 361...
#     Created smanni+train_so100_all-episode_362 with 597 frames
#   Processing episode 362...
#     Created smanni+train_so100_all-episode_363 with 597 frames
#   Processing episode 363...
#     Created smanni+train_so100_all-episode_364 with 597 frames
#   Processing episode 364...
#     Created smanni+train_so100_all-episode_365 with 597 frames
#   Processing episode 365...
#     Created smanni+train_so100_all-episode_366 with 597 frames
#   Processing episode 366...
#     Created smanni+train_so100_all-episode_367 with 597 frames
#   Processing episode 367...
#     Created smanni+train_so100_all-episode_368 with 597 frames
#   Processing episode 368...
#     Created smanni+train_so100_all-episode_369 with 597 frames
#   Processing episode 369...
#     Created smanni+train_so100_all-episode_370 with 597 frames
#   Processing episode 370...
#     Created smanni+train_so100_all-episode_371 with 597 frames
#   Processing episode 371...
#     Created smanni+train_so100_all-episode_372 with 597 frames
#   Processing episode 372...
#     Created smanni+train_so100_all-episode_373 with 597 frames
#   Processing episode 373...
#     Created smanni+train_so100_all-episode_374 with 597 frames
#   Processing episode 374...
#     Created smanni+train_so100_all-episode_375 with 597 frames
#   Processing episode 375...
#     Created smanni+train_so100_all-episode_376 with 597 frames
#   Processing episode 376...
#     Created smanni+train_so100_all-episode_377 with 597 frames
#   Processing episode 377...
#     Created smanni+train_so100_all-episode_378 with 597 frames
#   Processing episode 378...
#     Created smanni+train_so100_all-episode_379 with 597 frames
#   Processing episode 379...
#     Created smanni+train_so100_all-episode_380 with 597 frames
#   Processing episode 380...
#     Created smanni+train_so100_all-episode_381 with 597 frames
#   Processing episode 381...
#     Created smanni+train_so100_all-episode_382 with 597 frames
#   Processing episode 382...
# ...
#     Created smanni+train_so100_all-episode_837 with 597 frames
#   Processing episode 837...
#     Created smanni+train_so100_all-episode_838 with 597 frames
#   Processing episode 838...
#     Created smanni+train_so100_all-episode_839 with 597 frames
#   Processing episode 839...
#     Created smanni+train_so100_all-episode_840 with 597 frames
#   Processing episode 840...
#     Created smanni+train_so100_all-episode_841 with 597 frames
#   Processing episode 841...
#     Created smanni+train_so100_all-episode_842 with 597 frames
#   Processing episode 842...
#     Created smanni+train_so100_all-episode_843 with 597 frames
#   Processing episode 843...
#     Created smanni+train_so100_all-episode_844 with 597 frames
#   Processing episode 844...
#     Created smanni+train_so100_all-episode_845 with 597 frames
#   Processing episode 845...
#     Created smanni+train_so100_all-episode_846 with 597 frames
#   Processing episode 846...
#     Created smanni+train_so100_all-episode_847 with 597 frames
#   Processing episode 847...
#     Created smanni+train_so100_all-episode_848 with 597 frames
#   Processing episode 848...
#     Created smanni+train_so100_all-episode_849 with 597 frames
#   Processing episode 849...
#     Created smanni+train_so100_all-episode_850 with 597 frames
#   Processing episode 850...
#     Created smanni+train_so100_all-episode_851 with 597 frames
#   Processing episode 851...
#     Created smanni+train_so100_all-episode_852 with 597 frames
#   Processing episode 852...
#     Created smanni+train_so100_all-episode_853 with 597 frames
#   Processing episode 853...
#     Created smanni+train_so100_all-episode_854 with 597 frames
#   Processing episode 854...
#     Created smanni+train_so100_all-episode_855 with 597 frames
#   Processing episode 855...
#     Created smanni+train_so100_all-episode_856 with 597 frames
#   Processing episode 856...
#     Created smanni+train_so100_all-episode_857 with 597 frames
#   Processing episode 857...
#     Created smanni+train_so100_all-episode_858 with 597 frames
#   Processing episode 858...
#     Created smanni+train_so100_all-episode_859 with 597 frames
#   Processing episode 859...
#     Created smanni+train_so100_all-episode_860 with 597 frames
#   Processing episode 860...
#     Created smanni+train_so100_all-episode_861 with 597 frames
#   Processing episode 861...
#     Created smanni+train_so100_all-episode_862 with 597 frames
#   Processing episode 862...
#     Created smanni+train_so100_all-episode_863 with 597 frames
#   Processing episode 863...
#     Created smanni+train_so100_all-episode_864 with 597 frames
#   Processing episode 864...
#     Created smanni+train_so100_all-episode_865 with 598 frames
#   Processing episode 865...
#     Created smanni+train_so100_all-episode_866 with 597 frames
#   Processing episode 866...
#     Created smanni+train_so100_all-episode_867 with 597 frames
#   Processing episode 867...
#     Created smanni+train_so100_all-episode_868 with 597 frames
#   Processing episode 868...
#     Created smanni+train_so100_all-episode_869 with 597 frames
#   Processing episode 869...
#     Created smanni+train_so100_all-episode_870 with 597 frames
#   Processing episode 870...
#     Created smanni+train_so100_all-episode_871 with 597 frames
#   Processing episode 871...
#     Created smanni+train_so100_all-episode_872 with 597 frames
#   Processing episode 872...
#     Created smanni+train_so100_all-episode_873 with 597 frames
#   Processing episode 873...
#     Created smanni+train_so100_all-episode_874 with 597 frames
#   Processing episode 874...
#     Created smanni+train_so100_all-episode_875 with 597 frames
#   Processing episode 875...
#     Created smanni+train_so100_all-episode_876 with 597 frames
#   Processing episode 876...
#     Created smanni+train_so100_all-episode_877 with 597 frames
#   Processing episode 877...
#     Created smanni+train_so100_all-episode_878 with 597 frames
#   Processing episode 878...
#     Created smanni+train_so100_all-episode_879 with 597 frames
#   Processing episode 879...
#     Created smanni+train_so100_all-episode_880 with 597 frames
#   Processing episode 880...
#     Created smanni+train_so100_all-episode_881 with 597 frames
#   Processing episode 881...
#     Created smanni+train_so100_all-episode_882 with 597 frames
#   Processing episode 882...
#     Created smanni+train_so100_all-episode_883 with 597 frames
#   Processing episode 883...
#     Created smanni+train_so100_all-episode_884 with 597 frames
#   Processing episode 884...
#     Created smanni+train_so100_all-episode_885 with 597 frames
#   Processing episode 885...
#     Created smanni+train_so100_all-episode_886 with 597 frames
#   Processing episode 886...
#     Created smanni+train_so100_all-episode_887 with 597 frames
#   Processing episode 887...
#     Created smanni+train_so100_all-episode_888 with 598 frames
#   Processing episode 888...
#     Created smanni+train_so100_all-episode_889 with 597 frames
#   Processing episode 889...
#     Created smanni+train_so100_all-episode_890 with 597 frames
#   Processing episode 890...
#     Created smanni+train_so100_all-episode_891 with 597 frames
#   Processing episode 891...
#     Created smanni+train_so100_all-episode_892 with 597 frames
#   Processing episode 892...
#     Created smanni+train_so100_all-episode_893 with 597 frames
#   Processing episode 893...
#     Created smanni+train_so100_all-episode_894 with 597 frames
#   Processing episode 894...
#     Created smanni+train_so100_all-episode_895 with 597 frames
#   Processing episode 895...
#     Created smanni+train_so100_all-episode_896 with 597 frames
#   Processing episode 896...
#     Created smanni+train_so100_all-episode_897 with 597 frames
#   Processing episode 897...
#     Created smanni+train_so100_all-episode_898 with 597 frames
#   Processing episode 898...
#     Created smanni+train_so100_all-episode_899 with 597 frames
#   Processing episode 899...
#     Created smanni+train_so100_all-episode_900 with 597 frames
#   Completed dataset 'smanni+train_so100_all': 900 episodes
#
# Processing dataset 'bjb7+so101_pen_touch_test_1' from /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/bjb7/so101_pen_touch_test_1
#   Processing episode 0...
#     Created bjb7+so101_pen_touch_test_1-episode_001 with 226 frames
#   Processing episode 1...
#     Created bjb7+so101_pen_touch_test_1-episode_002 with 353 frames
#   Processing episode 2...
#     Created bjb7+so101_pen_touch_test_1-episode_003 with 182 frames
#   Processing episode 3...
#     Created bjb7+so101_pen_touch_test_1-episode_004 with 206 frames
#   Processing episode 4...
#     Created bjb7+so101_pen_touch_test_1-episode_005 with 384 frames
#   Processing episode 5...
#     Created bjb7+so101_pen_touch_test_1-episode_006 with 273 frames
#   Processing episode 6...
#     Created bjb7+so101_pen_touch_test_1-episode_007 with 282 frames
#   Processing episode 7...
#     Created bjb7+so101_pen_touch_test_1-episode_008 with 156 frames
#   Processing episode 8...
#     Created bjb7+so101_pen_touch_test_1-episode_009 with 250 frames
#   Processing episode 9...
#     Created bjb7+so101_pen_touch_test_1-episode_010 with 214 frames
#   Processing episode 10...
#     Created bjb7+so101_pen_touch_test_1-episode_011 with 173 frames
#   Processing episode 11...
#     Created bjb7+so101_pen_touch_test_1-episode_012 with 201 frames
#   Processing episode 12...
#     Created bjb7+so101_pen_touch_test_1-episode_013 with 178 frames
#   Processing episode 13...
#     Created bjb7+so101_pen_touch_test_1-episode_014 with 157 frames
#   Processing episode 14...
#     Created bjb7+so101_pen_touch_test_1-episode_015 with 150 frames
#   Processing episode 15...
#     Created bjb7+so101_pen_touch_test_1-episode_016 with 147 frames
#   Processing episode 16...
#     Created bjb7+so101_pen_touch_test_1-episode_017 with 137 frames
#   Processing episode 17...
#     Created bjb7+so101_pen_touch_test_1-episode_018 with 136 frames
#   Processing episode 18...
#     Created bjb7+so101_pen_touch_test_1-episode_019 with 133 frames
#   Processing episode 19...
#     Created bjb7+so101_pen_touch_test_1-episode_020 with 141 frames
#   Processing episode 20...
#     Created bjb7+so101_pen_touch_test_1-episode_021 with 176 frames
#   Processing episode 21...
#     Created bjb7+so101_pen_touch_test_1-episode_022 with 193 frames
#   Processing episode 22...
#     Created bjb7+so101_pen_touch_test_1-episode_023 with 174 frames
#   Processing episode 23...
#     Created bjb7+so101_pen_touch_test_1-episode_024 with 161 frames
#   Processing episode 24...
#     Created bjb7+so101_pen_touch_test_1-episode_025 with 175 frames
#   Processing episode 25...
#     Created bjb7+so101_pen_touch_test_1-episode_026 with 270 frames
#   Processing episode 26...
#     Created bjb7+so101_pen_touch_test_1-episode_027 with 256 frames
#   Processing episode 27...
#     Created bjb7+so101_pen_touch_test_1-episode_028 with 171 frames
#   Processing episode 28...
#     Created bjb7+so101_pen_touch_test_1-episode_029 with 202 frames
#   Processing episode 29...
#     Created bjb7+so101_pen_touch_test_1-episode_030 with 175 frames
#   Processing episode 30...
#     Created bjb7+so101_pen_touch_test_1-episode_031 with 206 frames
#   Processing episode 31...
#     Created bjb7+so101_pen_touch_test_1-episode_032 with 178 frames
#   Processing episode 32...
#     Created bjb7+so101_pen_touch_test_1-episode_033 with 265 frames
#   Processing episode 33...
#     Created bjb7+so101_pen_touch_test_1-episode_034 with 338 frames
#   Processing episode 34...
#     Created bjb7+so101_pen_touch_test_1-episode_035 with 191 frames
#   Processing episode 35...
#     Created bjb7+so101_pen_touch_test_1-episode_036 with 157 frames
#   Processing episode 36...
#     Created bjb7+so101_pen_touch_test_1-episode_037 with 191 frames
#   Processing episode 37...
#     Created bjb7+so101_pen_touch_test_1-episode_038 with 253 frames
#   Processing episode 38...
#     Created bjb7+so101_pen_touch_test_1-episode_039 with 227 frames
#   Processing episode 39...
#     Created bjb7+so101_pen_touch_test_1-episode_040 with 184 frames
#   Processing episode 40...
#     Created bjb7+so101_pen_touch_test_1-episode_041 with 238 frames
#   Processing episode 41...
#     Created bjb7+so101_pen_touch_test_1-episode_042 with 229 frames
#   Processing episode 42...
#     Created bjb7+so101_pen_touch_test_1-episode_043 with 206 frames
#   Processing episode 43...
#     Created bjb7+so101_pen_touch_test_1-episode_044 with 395 frames
#   Processing episode 44...
#     Created bjb7+so101_pen_touch_test_1-episode_045 with 253 frames
#   Processing episode 45...
#     Created bjb7+so101_pen_touch_test_1-episode_046 with 266 frames
#   Processing episode 46...
#     Created bjb7+so101_pen_touch_test_1-episode_047 with 228 frames
#   Processing episode 47...
#     Created bjb7+so101_pen_touch_test_1-episode_048 with 331 frames
#   Processing episode 48...
#     Created bjb7+so101_pen_touch_test_1-episode_049 with 179 frames
#   Processing episode 49...
#     Created bjb7+so101_pen_touch_test_1-episode_050 with 272 frames
#   Processing episode 50...
#     Created bjb7+so101_pen_touch_test_1-episode_051 with 433 frames
#   Processing episode 51...
#     Created bjb7+so101_pen_touch_test_1-episode_052 with 435 frames
#   Processing episode 52...
#     Created bjb7+so101_pen_touch_test_1-episode_053 with 240 frames
#   Processing episode 53...
#     Created bjb7+so101_pen_touch_test_1-episode_054 with 149 frames
#   Processing episode 54...
#     Created bjb7+so101_pen_touch_test_1-episode_055 with 250 frames
#   Processing episode 55...
#     Created bjb7+so101_pen_touch_test_1-episode_056 with 157 frames
#   Processing episode 56...
#     Created bjb7+so101_pen_touch_test_1-episode_057 with 265 frames
#   Processing episode 57...
#     Created bjb7+so101_pen_touch_test_1-episode_058 with 283 frames
#   Processing episode 58...
#     Created bjb7+so101_pen_touch_test_1-episode_059 with 148 frames
#   Processing episode 59...
#     Created bjb7+so101_pen_touch_test_1-episode_060 with 204 frames
#   Processing episode 60...
#     Created bjb7+so101_pen_touch_test_1-episode_061 with 211 frames
#   Processing episode 61...
#     Created bjb7+so101_pen_touch_test_1-episode_062 with 209 frames
#   Processing episode 62...
#     Created bjb7+so101_pen_touch_test_1-episode_063 with 299 frames
#   Processing episode 63...
#     Created bjb7+so101_pen_touch_test_1-episode_064 with 261 frames
#   Processing episode 64...
#     Created bjb7+so101_pen_touch_test_1-episode_065 with 265 frames
#   Processing episode 65...
#     Created bjb7+so101_pen_touch_test_1-episode_066 with 179 frames
#   Processing episode 66...
#     Created bjb7+so101_pen_touch_test_1-episode_067 with 1 frames
#   Processing episode 67...
#     Created bjb7+so101_pen_touch_test_1-episode_068 with 1 frames
#   Processing episode 68...
#     Created bjb7+so101_pen_touch_test_1-episode_069 with 22 frames
#   Processing episode 69...
#     Created bjb7+so101_pen_touch_test_1-episode_070 with 216 frames
#   Processing episode 70...
#     Created bjb7+so101_pen_touch_test_1-episode_071 with 202 frames
#   Processing episode 71...
#     Created bjb7+so101_pen_touch_test_1-episode_072 with 111 frames
#   Processing episode 72...
#     Created bjb7+so101_pen_touch_test_1-episode_073 with 246 frames
#   Processing episode 73...
#     Created bjb7+so101_pen_touch_test_1-episode_074 with 238 frames
#   Processing episode 74...
#     Created bjb7+so101_pen_touch_test_1-episode_075 with 168 frames
#   Processing episode 75...
#     Created bjb7+so101_pen_touch_test_1-episode_076 with 180 frames
#   Processing episode 76...
#     Created bjb7+so101_pen_touch_test_1-episode_077 with 176 frames
#   Processing episode 77...
#     Created bjb7+so101_pen_touch_test_1-episode_078 with 251 frames
#   Processing episode 78...
#     Created bjb7+so101_pen_touch_test_1-episode_079 with 287 frames
#   Processing episode 79...
#     Created bjb7+so101_pen_touch_test_1-episode_080 with 175 frames
#   Processing episode 80...
#     Created bjb7+so101_pen_touch_test_1-episode_081 with 249 frames
#   Processing episode 81...
#     Created bjb7+so101_pen_touch_test_1-episode_082 with 156 frames
#   Processing episode 82...
#     Created bjb7+so101_pen_touch_test_1-episode_083 with 211 frames
#   Processing episode 83...
#     Created bjb7+so101_pen_touch_test_1-episode_084 with 249 frames
#   Processing episode 84...
#     Created bjb7+so101_pen_touch_test_1-episode_085 with 184 frames
#   Processing episode 85...
#     Created bjb7+so101_pen_touch_test_1-episode_086 with 247 frames
#   Processing episode 86...
#     Created bjb7+so101_pen_touch_test_1-episode_087 with 307 frames
#   Processing episode 87...
#     Created bjb7+so101_pen_touch_test_1-episode_088 with 172 frames
#   Processing episode 88...
#     Created bjb7+so101_pen_touch_test_1-episode_089 with 230 frames
#   Processing episode 89...
#     Created bjb7+so101_pen_touch_test_1-episode_090 with 175 frames
#   Processing episode 90...
#     Created bjb7+so101_pen_touch_test_1-episode_091 with 324 frames
#   Processing episode 91...
#     Created bjb7+so101_pen_touch_test_1-episode_092 with 250 frames
#   Processing episode 92...
#     Created bjb7+so101_pen_touch_test_1-episode_093 with 214 frames
#   Processing episode 93...
#     Created bjb7+so101_pen_touch_test_1-episode_094 with 195 frames
#   Processing episode 94...
#     Created bjb7+so101_pen_touch_test_1-episode_095 with 231 frames
#   Processing episode 95...
#     Created bjb7+so101_pen_touch_test_1-episode_096 with 224 frames
#   Processing episode 96...
#     Created bjb7+so101_pen_touch_test_1-episode_097 with 351 frames
#   Processing episode 97...
#     Created bjb7+so101_pen_touch_test_1-episode_098 with 239 frames
#   Processing episode 98...
#     Created bjb7+so101_pen_touch_test_1-episode_099 with 178 frames
#   Processing episode 99...
#     Created bjb7+so101_pen_touch_test_1-episode_100 with 181 frames
#   Completed dataset 'bjb7+so101_pen_touch_test_1': 100 episodes
# Warning: Input dataset not found: /home/michelmeyer/Dev/LeRobotLab/downloaded_datasets/shreyasgite/so100_base_env
#
# Consolidation complete!
# Total episodes created: 1135
# Output directory: /home/michelmeyer/Dev/LeRobotLab/output_datasets/vjepa_layout
# Dataset list saved to: /home/michelmeyer/Dev/LeRobotLab/output_datasets/vjepa_layout/dataset_list.txt
# All datasets consolidated into: /home/michelmeyer/Dev/LeRobotLab/output_datasets/vjepa_layout

# %% [markdown]
# ## Verify Output
#
# Check the results of the conversion:

# %%
def verify_output(output_path):
    """Verify the output directory structure"""
    output_path = Path(output_path)
    
    # Check if output directory exists
    if not output_path.exists():
        print(f"Output directory not found: {output_path}")
        return
        
    # Check if dataset_list.txt exists
    dataset_list_path = output_path / "dataset_list.txt"
    if not dataset_list_path.exists():
        print(f"Dataset list file not found: {dataset_list_path}")
        return
    
    # Read dataset_list.txt
    with open(dataset_list_path, 'r') as f:
        episode_paths = [line.strip() for line in f.readlines()]
    
    print(f"Dataset list contains {len(episode_paths)} episodes")
    
    # Check episodes directory
    episodes_dir = output_path / "episodes"
    if not episodes_dir.exists():
        print(f"Episodes directory not found: {episodes_dir}")
        return
    
    # Count episode directories
    episode_dirs = list(episodes_dir.glob("*"))
    print(f"Episodes directory contains {len(episode_dirs)} episode folders")
    
    # Check structure of a few episodes
    if episode_dirs:
        num_to_check = min(3, len(episode_dirs))
        print(f"\nChecking {num_to_check} episode folders:")
        
        for i, episode_dir in enumerate(episode_dirs[:num_to_check]):
            print(f"\nEpisode {i+1}: {episode_dir.name}")
            
            # Check metadata.json
            metadata_path = episode_dir / "metadata.json"
            if metadata_path.exists():
                print("  ✓ metadata.json")
            else:
                print("  ✗ metadata.json not found")
            
            # Check trajectory.h5
            trajectory_path = episode_dir / "trajectory.h5"
            if trajectory_path.exists():
                print("  ✓ trajectory.h5")
            else:
                print("  ✗ trajectory.h5 not found")
            
            # Check video file
            video_path = episode_dir / "recordings" / "MP4" / "front_camera.mp4"
            if video_path.exists():
                print("  ✓ front_camera.mp4")
            else:
                print("  ✗ front_camera.mp4 not found")

# Verify the output
verify_output(OUTPUT_DATASETS_DIRECTORY)
# Out:
# Dataset list contains 1135 episodes
# Episodes directory contains 1135 episode folders
#
# Checking 3 episode folders:
#
# Episode 1: smanni+train_so100_all-episode_499
#   ✓ metadata.json
#   ✓ trajectory.h5
#   ✓ front_camera.mp4
#
# Episode 2: smanni+train_so100_all-episode_659
#   ✓ metadata.json
#   ✓ trajectory.h5
#   ✓ front_camera.mp4
#
# Episode 3: smanni+train_so100_all-episode_180
#   ✓ metadata.json
#   ✓ trajectory.h5
#   ✓ front_camera.mp4
