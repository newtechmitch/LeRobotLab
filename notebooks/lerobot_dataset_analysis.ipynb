# %% [markdown]
# # LeRobot Dataset Analysis
#
# This notebook analyzes the dataset `1lyz123576/so101_test` using the custom `LeRobotDataset` class from the `lerobotlab` module.

# %%
# Import necessary libraries
import sys
from pathlib import Path

# Add the parent directory to sys.path
parent_dir = Path.cwd().parent
sys.path.append(str(parent_dir))

# Now import from lerobotlab directly
from lerobotlab.lerobot_dataset import LeRobotDataset

# Load the dataset
repo_id = "1lyz123576/so101_test"
print(f"Loading dataset: {repo_id}")

# Initialize LeRobotDataset
lerobot_dataset = LeRobotDataset(repo_id)

# Load the dataset using LeRobotDataset
lerobot_dataset.load()

# Print the dataset contents
lerobot_dataset.print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 else:
#       8     raise FileNotFoundError(f"Module path not found: {lerobotlab_path}")
# ---> 10 from lerobotlab.lerobot_dataset import LeRobotDataset
#      12 # Load the dataset
#      13 repo_id = "1lyz123576/so101_test"
#
# ModuleNotFoundError: No module named 'lerobotlab'

# %% [markdown]
# # Dataset Exploration
#
# Explore the structure and features of the dataset.

# %%
# Explore dataset structure
if lerobot_dataset.data:
    print(f"Dataset features: {lerobot_dataset.data.features}")
    print(f"Number of samples in train split: {len(lerobot_dataset.data)}")
else:
    print("Dataset could not be loaded.")

# %% [markdown]
# # Visualize Dataset
#
# Visualize key aspects of the dataset, such as joint trajectories and gripper positions.

# %%
# Visualize joint trajectories and gripper positions
if lerobot_dataset.data:
    JOINT_NAMES = [
        "Joint1_Rotation",
        "Joint2_Pitch",
        "Joint3_Elbow",
        "Joint4_Wrist_Pitch",
        "Joint5_Wrist_Roll",
        "Joint6_Jaw"
    ]

    # Example visualization logic (to be implemented based on dataset structure)
    print("Visualization logic goes here.")
else:
    print("Visualization skipped due to dataset loading issues.")
